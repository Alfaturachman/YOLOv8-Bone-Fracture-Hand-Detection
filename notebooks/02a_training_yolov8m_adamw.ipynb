# %% [markdown]
# # Notebook 02 — Model Training
# **FracAtlas YOLOv8m Fracture Detection Pipeline**
#
# Trains a YOLOv8m model on the prepared dataset with medical-imaging–optimized
# hyperparameters and augmentation strategy.
#
# > **Notebook 01 must be completed successfully before running this notebook.**

# %%
import os, yaml, torch
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt
import pandas as pd

# ─── Verify GPU ───────────────────────────────────────────────────────────────
print("PyTorch version :", torch.__version__)
print("CUDA available  :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU             :", torch.cuda.get_device_name(0))
    print("VRAM            :", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 2), "GB")
else:
    print("No GPU detected — training will be slow on CPU.")
# Out:
# PyTorch version : 2.7.1+cu118
# CUDA available  : True
# GPU             : NVIDIA GeForce RTX 3050 Laptop GPU
# VRAM            : 4.29 GB

# %% [markdown]
# ## 1. Configuration

# %%
# ─── PATHS ────────────────────────────────────────────────────────────────────
BASE_DIR = Path("D:/Project Medical Object Detection/FracAtlas")
YAML_PATH = BASE_DIR / "fracatlas_hand_oversampled.yaml"
RUNS_DIR  = BASE_DIR / "runs" / "detect"

# ─── MODEL ────────────────────────────────────────────────────────────────────
# Use 'yolov8s' is the balanced choice for medical imaging with augmented dataset.
# Use 'yolov8n.pt' for quick experiments,
# Use 'yolov8l.pt' for max accuracy.
MODEL_WEIGHTS = "yolov8m.pt"   # Will be downloaded automatically if not present
RUN_NAME      = "fracatlas_yolov8m_adamw"

# ─── CORE HYPERPARAMETERS ────────────────────────────────────────────────────
IMGSZ      = 640      # Keep large — X-rays have fine-detail fractures
EPOCHS     = 100
BATCH_SIZE = 4       # Reduce to 4 if CUDA OOM; increase to 16 if >16 GB VRAM
PATIENCE   = 20       # Early stopping patience (epochs without improvement)
WORKERS    = 2        # DataLoader workers

# ─── MEDICAL-OPTIMISED AUGMENTATION ──────────────────────────────────────────
# Conservative augmentations that respect anatomical structure
AUGMENTATION = dict(
    degrees   = 10.0,   # ±10° rotation — simulates patient positioning
    translate = 0.05,   # Small translation
    scale     = 0.2,    # Mild scale variation
    shear     = 0.0,    # Disabled — distorts anatomy
    perspective = 0.0,  # Disabled — X-rays are projections
    flipud    = 0.0,    # Disabled — anatomical orientation matters
    fliplr    = 0.5,    # OK for symmetric anatomy (arms/legs)
    mosaic    = 0.5,    # Reduced from 1.0 — helps but can create artifacts
    mixup     = 0.1,    # Light mixup
    copy_paste = 0.0,   # Disabled for medical
    hsv_h     = 0.0,    # X-rays are grayscale — no hue shift
    hsv_s     = 0.0,    # No saturation shift
    hsv_v     = 0.2,    # Mild brightness variation (simulate exposure differences)
)

print("- Configuration loaded")
print(f"   Model    : {MODEL_WEIGHTS}")
print(f"   YAML     : {YAML_PATH.resolve()}")
print(f"   Image sz : {IMGSZ}px")
print(f"   Epochs   : {EPOCHS} (patience={PATIENCE})")
print(f"   Batch    : {BATCH_SIZE}")
# Out:
# - Configuration loaded
#    Model    : yolov8m.pt
#    YAML     : D:\Project Medical Object Detection\FracAtlas\fracatlas_hand_oversampled.yaml
#    Image sz : 640px
#    Epochs   : 100 (patience=20)
#    Batch    : 4

# %% [markdown]
# ## 2. Inspect data.yaml

# %%
with open(YAML_PATH) as f:
    data_cfg = yaml.safe_load(f)

print("data.yaml contents:")
for k, v in data_cfg.items():
    print(f"  {k}: {v}")

# Quick sanity: check paths resolve
dataset_path = Path(data_cfg["path"])
for split in ["train", "val", "test"]:
    n = len(list((dataset_path / split / "images").iterdir()))
    print(f"  {split}: {n} images")
# Out:
# data.yaml contents:
#   path: D:/Project Medical Object Detection/FracAtlas/yolo_dataset_hand_oversampled
#   train: train/images
#   val: val/images
#   test: test/images
#   nc: 1
#   names: ['fracture']
#   train: 1690 images
#   val: 362 images
#   test: 362 images

# %% [markdown]
# ## 3. Class Distribution & Final Weighting

# %%
# FracAtlas was balanced via undersampling in Notebook 01 (Ratio ~1:2).
# We verify the final distribution and compute weights to guide the model.

label_dir_train = dataset_path / "train" / "labels"
n_frac     = sum(1 for f in label_dir_train.iterdir() if f.stat().st_size > 0)
n_non_frac = sum(1 for f in label_dir_train.iterdir() if f.stat().st_size == 0)
n_total    = n_frac + n_non_frac

# Weight = total / (n_classes * n_samples_for_class)
weight_frac = n_total / (2 * n_frac) if n_frac > 0 else 1.0

print(f"Final Train set distribution:")
print(f"  Fractured    : {n_frac:>5}  ({100*n_frac/n_total:.1f}%)")
print(f"  Non-fractured: {n_non_frac:>5}  ({100*n_non_frac/n_total:.1f}%)")
print(f"  Class weight (fracture): {weight_frac:.2f}")
print()
print("ℹ- We handle the remaining imbalance via:")
print("   1. Undersampling (Done in Notebook 01)")
print("   2. Class weights in loss function (computed above)")
print("   3. Mosaic augmentation (helps model see more fracture examples)")
# Out:
# Final Train set distribution:
#   Fractured    :   920  (54.4%)
#   Non-fractured:   770  (45.6%)
#   Class weight (fracture): 0.92
#
# ℹ- We handle the remaining imbalance via:
#    1. Undersampling (Done in Notebook 01)
#    2. Class weights in loss function (computed above)
#    3. Mosaic augmentation (helps model see more fracture examples)

# %% [markdown]
# ## 4. Load Model

# %%
# Load pretrained yolov8s backbone (downloads ~40MB if not present)
model = YOLO(MODEL_WEIGHTS)
print(f"- Model loaded: {MODEL_WEIGHTS}")
print(f"   Parameters: {sum(p.numel() for p in model.model.parameters()):,}")
# Out:
# - Model loaded: yolov8m.pt
#    Parameters: 25,902,640

# %% [markdown]
# ## 5. Train

# %%
# ─── TRAINING ─────────────────────────────────────────────────────────────────
# All augmentation kwargs are passed directly to model.train()
results = model.train(
    data       = str(YAML_PATH),
    imgsz      = IMGSZ,
    epochs     = EPOCHS,
    batch      = BATCH_SIZE,
    patience   = PATIENCE,
    workers    = WORKERS,
    project    = str(RUNS_DIR),
    name       = RUN_NAME,
    exist_ok   = True,          # Overwrite if rerunning
    pretrained = True,
    optimizer  = "AdamW",       # AdamW
    lr0        = 0.001,         # TURUN dari 0.01 → biar tidak terlalu agresif
    lrf        = 0.01,
    momentum   = 0.9,           # Default AdamW
    weight_decay  = 0.0001,     # Lebih kecil → preserve detail kecil fracture
    warmup_epochs = 5,          # Extended warmup for stability
    warmup_momentum = 0.8,
    box        = 7.5,           # Box loss gain
    cls        = 0.5,           # Class loss gain
    dfl        = 1.5,
    # Augmentation
    **AUGMENTATION,
    # Output
    save       = True,
    save_period = 10,           # Save checkpoint every 10 epochs
    plots      = True,
    verbose    = True,
    amp        = True,          # Automatic Mixed Precision (saves VRAM)
    cache      = False,         # Set True if RAM > 32 GB to speed up
    rect       = True,         # Rectangular training — disable for mixed sizes
    cos_lr     = True,          # Cosine LR scheduler
    label_smoothing = 0.1,      # Slight label smoothing helps generalisation
    val        = True,
)

print("\n- Training complete!")
print(f"Best weights saved to: {RUNS_DIR / RUN_NAME / 'weights' / 'best.pt'}")
# Out:
# New https://pypi.org/project/ultralytics/8.4.41 available  Update with 'pip install -U ultralytics'
# WARNING 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.21  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=D:\Project Medical Object Detection\FracAtlas\fracatlas_hand_oversampled.yaml, degrees=10.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.2, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8m.pt, momentum=0.9, mosaic=0.5, multi_scale=0.0, name=fracatlas_yolov8m_adamw, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=D:\Project Medical Object Detection\FracAtlas\runs\detect, rect=True, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.2, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.05, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0001, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, 16, None, [192, 384, 576]]
# Model summary: 170 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 139.047.8 MB/s, size: 23.9 KB)
# train: Scanning D:\Project Medical Object Detection\FracAtlas\yolo_dataset_hand_oversampled\train\labels.cache... 1690 images, 770 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1690/1690  0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING 'rect=True' is incompatible with DataLoader shuffle, setting shuffle=False
# val: Fast image access  (ping: 0.40.1 ms, read: 85.6138.9 MB/s, size: 195.0 KB)
# val: Scanning D:\Project Medical Object Detection\FracAtlas\yolo_dataset_hand_oversampled\val\labels.cache... 362 images, 165 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362  0.0s
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0001), 83 bias(decay=0.0)
# Plotting labels to D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.93G      2.322      3.608      1.651          1        512: 100% ━━━━━━━━━━━━ 423/423 4.5it/s 1:35<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 4.6it/s 9.9s0.1ss
#                    all        362        241     0.0828     0.0996     0.0241    0.00546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.02G      2.125      3.137      1.549          1        512: 100% ━━━━━━━━━━━━ 423/423 4.3it/s 1:39<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.0it/s 7.6s0.1s
#                    all        362        241       0.42     0.0996      0.109     0.0353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.19G      2.069       2.92      1.508          1        512: 100% ━━━━━━━━━━━━ 423/423 4.2it/s 1:42<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.7s0.1s
#                    all        362        241      0.155      0.147       0.08     0.0253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.19G      2.107      2.843       1.56          1        512: 100% ━━━━━━━━━━━━ 423/423 4.2it/s 1:41<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46
0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.19G      1.221     0.9273      1.016          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.7s0.2s
#                    all        362        241      0.753      0.635      0.705      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100       2.2G      1.184     0.8927      1.001          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.813      0.635      0.712      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.18G      1.223     0.8709       1.02          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.6s0.2s
#                    all        362        241      0.724      0.664      0.702      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.18G      1.204     0.8773     0.9991          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.4s0.1s
#                    all        362        241      0.891       0.56      0.705      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.18G      1.207      0.822      1.007          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.6s0.1s
#                    all        362        241      0.735      0.631      0.697      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100       2.2G      1.165      0.799     0.9933          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.743      0.643      0.704      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.17G      1.157      0.789     0.9787          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.6s0.2s
#                    all        362        241      0.725      0.668      0.744       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.08G       1.16     0.7718     0.9843          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.6s0.1s
#                    all        362        241       0.82      0.639      0.751      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100       2.2G      1.116     0.7682     0.9604          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.795       0.68      0.736      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.18G      1.119     0.7141     0.9628          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.2s
#                    all        362        241      0.851      0.642      0.765      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.19G      1.094      0.691     0.9481          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.8it/s 6.8s0.1s
#                    all        362        241      0.824        0.7       0.77      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.19G      1.098     0.6997     0.9512          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.5s0.1s
#                    all        362        241      0.804      0.715      0.771      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.19G      1.114     0.6839     0.9566          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.7s0.1s
#                    all        362        241      0.877       0.71      0.799      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100       2.2G       1.09     0.6494     0.9432          1        512: 100% ━━━━━━━━━━━━ 423/423 5.2it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.8it/s 6.8s0.1s
#                    all        362        241      0.801      0.734      0.783      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.19G      1.094     0.6835     0.9476          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.6s0.1s
#                    all        362        241      0.889      0.676      0.785      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.19G      1.058      0.631     0.9239          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.7s0.1s
#                    all        362        241      0.815      0.726      0.794      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.19G      1.059     0.6183     0.9259          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.813      0.726      0.808        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.19G      1.051     0.6073     0.9192          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.4s0.1s
#                    all        362        241      0.847      0.688      0.768       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.18G      1.035     0.6055     0.9121          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.794       0.73       0.79      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.19G      1.012     0.5802     0.8963          1        512: 100% ━━━━━━━━━━━━ 423/423 10.4s/it 1:12:600.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.6it/s 6.1s0.1s
#                    all        362        241      0.864      0.709      0.794      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.19G      1.009     0.5848     0.9025          1        512: 100% ━━━━━━━━━━━━ 423/423 5.3it/s 1:20<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.3it/s 6.3s0.1s
#                    all        362        241        0.8      0.763      0.798      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.18G     0.9805     0.5745     0.8935          1        512: 100% ━━━━━━━━━━━━ 423/423 5.2it/s 1:21<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.5s0.1s
#                    all        362        241       0.82      0.726      0.798       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.17G      1.003     0.5771     0.9044          1        512: 100% ━━━━━━━━━━━━ 423/423 5.2it/s 1:22<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.5s0.1s
#                    all        362        241      0.841      0.703      0.771      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.08G     0.9648     0.5569     0.8743          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.2it/s 6.4s0.1s
#                    all        362        241      0.827      0.734      0.779      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.19G     0.9676     0.5599      0.889          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.2it/s 6.3s0.1s
#                    all        362        241      0.852      0.701      0.795      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.19G     0.9454     0.5502     0.8735          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.844      0.739      0.807      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.19G     0.9295     0.5201      0.873          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.2it/s 6.4s0.1s
#                    all        362        241      0.845      0.747      0.812      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.19G     0.9306     0.5327     0.8647          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.6s0.1s
#                    all        362        241      0.888      0.726      0.824      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.18G      0.885      0.511     0.8483          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.917      0.691      0.819      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.19G     0.8747     0.5183     0.8419          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.2it/s 6.4s0.1s
#                    all        362        241      0.847      0.743      0.822       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.19G     0.8463     0.4828     0.8291          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.893       0.71      0.821      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.19G      0.864     0.4852     0.8426          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.5s0.1s
#                    all        362        241      0.897      0.722      0.816      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.19G     0.8504     0.4791      0.828          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.2it/s 6.4s0.1s
#                    all        362        241      0.824      0.768      0.827      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.19G     0.8586     0.4787      0.839          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.844      0.744      0.827      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.19G     0.8213     0.4787     0.8208          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.7s0.1s
#                    all        362        241      0.863      0.707      0.813      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.18G     0.8248     0.4634     0.8201          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.2it/s 6.4s0.1s
#                    all        362        241      0.885      0.734       0.82      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.19G     0.8361     0.4663     0.8209          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.885      0.739      0.832      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.18G      0.826     0.4561     0.8253          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.893      0.725      0.828      0.422
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.18G     0.8306     0.4501     0.8163          1        512: 100% ━━━━━━━━━━━━ 423/423 4.9it/s 1:26<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.825       0.78      0.824      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.08G     0.8254     0.4475     0.8238          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.885      0.726      0.829      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.19G      0.797       0.44     0.8098          1        512: 100% ━━━━━━━━━━━━ 423/423 5.0it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.901       0.72      0.827      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100       2.2G     0.8065      0.447     0.8123          1        512: 100% ━━━━━━━━━━━━ 423/423 5.0it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.9it/s 6.7s0.1s
#                    all        362        241      0.906      0.718      0.829      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.19G     0.8072     0.4508     0.8129          1        512: 100% ━━━━━━━━━━━━ 423/423 5.0it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.886      0.734      0.832      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.19G      0.797     0.4429     0.8094          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.6s0.1s
#                    all        362        241      0.908      0.736      0.834      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.19G     0.7827     0.4423     0.7951          1        512: 100% ━━━━━━━━━━━━ 423/423 5.0it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241      0.915      0.714      0.833      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.19G     0.8045     0.4431     0.8078          1        512: 100% ━━━━━━━━━━━━ 423/423 5.1it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 6.8it/s 6.7s0.1s
#                    all        362        241      0.911      0.726      0.838      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       2.2G     0.7931     0.4406     0.8086          1        512: 100% ━━━━━━━━━━━━ 423/423 5.0it/s 1:24<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.0it/s 6.5s0.1s
#                    all        362        241       0.91      0.715      0.828      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.19G     0.7939     0.4342     0.8117          1        512: 100% ━━━━━━━━━━━━ 423/423 4.9it/s 1:27<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.1it/s 6.5s0.1s
#                    all        362        241       0.91      0.718      0.833      0.437
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 80, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 100 epochs completed in 3.798 hours.
# Optimizer stripped from D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\weights\last.pt, 52.0MB
# Optimizer stripped from D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\weights\best.pt, 52.0MB
#
# Validating D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\weights\best.pt...
# Ultralytics 8.4.21  Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 93 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 7.8it/s 5.9s0.1s
#                    all        362        241      0.887      0.726      0.824      0.444
# Speed: 0.4ms preprocess, 12.4ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw
#
# - Training complete!
# Best weights saved to: D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\weights\best.pt

# %% [markdown]
# ## 6. Plot Training Curves

# %%
import matplotlib.pyplot as plt
import pandas as pd

results_csv = RUNS_DIR / RUN_NAME / "results.csv"

if results_csv.exists():
    df = pd.read_csv(results_csv)
    df.columns = df.columns.str.strip()   # Remove whitespace from col names
    print("Available columns:", df.columns.tolist())

    fig, axes = plt.subplots(2, 4, figsize=(20, 9))
    axes = axes.flatten()

    plot_cols = [
        ("train/box_loss", "Train Box Loss"),
        ("train/cls_loss", "Train Class Loss"),
        ("train/dfl_loss", "Train DFL Loss"),
        ("val/box_loss",   "Val Box Loss"),
        ("val/cls_loss",   "Val Class Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/recall(B)",   "Recall"),
    ]

    for ax, (col, title) in zip(axes, plot_cols):
        if col in df.columns:
            ax.plot(df["epoch"], df[col], linewidth=2)
            ax.set_title(title, fontsize=11, fontweight="bold")
            ax.set_xlabel("Epoch")
            ax.grid(True, alpha=0.3)
        else:
            ax.set_title(f"{title}\n(column not found)", fontsize=10)
            ax.axis('off')

    plt.suptitle("yolov8m Training Metrics — FracAtlas", fontsize=14, fontweight="bold")
    plt.tight_layout()
    save_path = BASE_DIR / "training_metrics.png"
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"Saved: {save_path}")
else:
    print(f"results.csv not found at {results_csv}")
# Out:
# Available columns: ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
# Saved: D:\Project Medical Object Detection\FracAtlas\training_metrics.png

# %% [markdown]
# ## 7. Best Model Summary

# %%
best_pt = RUNS_DIR / RUN_NAME / "weights" / "best.pt"
last_pt = RUNS_DIR / RUN_NAME / "weights" / "last.pt"

print("=" * 50)
print("  TRAINING SUMMARY")
print("=" * 50)
print(f"Best weights : {best_pt}")
print(f"Last weights : {last_pt}")
print(f"Best exists  : {best_pt.exists()}")

if results_csv.exists():
    df = pd.read_csv(results_csv)
    df.columns = df.columns.str.strip()

    if "metrics/mAP50(B)" in df.columns:
        best_row = df.loc[df["metrics/mAP50(B)"].idxmax()]

        print(f"\nBest epoch   : {int(best_row['epoch'])}")
        print(f"mAP@50       : {best_row['metrics/mAP50(B)']:.4f}")

        if "metrics/mAP50-95(B)" in df.columns:
            print(f"mAP@50-95    : {best_row['metrics/mAP50-95(B)']:.4f}")

        if "metrics/recall(B)" in df.columns:
            print(f"Recall       : {best_row['metrics/recall(B)']:.4f}")

        if "metrics/precision(B)" in df.columns:
            print(f"Precision    : {best_row['metrics/precision(B)']:.4f}")

        if "metrics/f1_score(B)" in df.columns:
            print(f"F1-score     : {best_row['metrics/f1_score(B)']:.4f}")

        if "metrics/specificity(B)" in df.columns:
            print(f"Specificity  : {best_row['metrics/specificity(B)']:.4f}")

print("\nProceed to Notebook 03 for evaluation.")
# Out:
# ==================================================
#   TRAINING SUMMARY
# ==================================================
# Best weights : D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\weights\best.pt
# Last weights : D:\Project Medical Object Detection\FracAtlas\runs\detect\fracatlas_yolov8m_adamw\weights\last.pt
# Best exists  : True
#
# Best epoch   : 98
# mAP@50       : 0.8377
# mAP@50-95    : 0.4289
# Recall       : 0.7264
# Precision    : 0.9115
#
# Proceed to Notebook 03 for evaluation.
